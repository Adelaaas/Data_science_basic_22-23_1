# %%
import pandas as pd

# %% [markdown]
# # №1

# %%
url1 = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/X_train.csv'
x_train = pd.read_csv(url1)
x_train.shape
# Out:
# (105058, 8)

# %%
url2 = "https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/studs_info.csv"
studs_info = pd.read_csv(url2)
studs_info.shape
# Out:
# (5466, 13)

# %%
url3 = "https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/y_train.csv"
y_train = pd.read_csv(url3)
y_train.shape
# Out:
# (105058, 2)

# %%
url4 = "https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/zachety.csv"
zachety = pd.read_csv(url4)
zachety.shape
# Out:
# (133223, 8)

# %% [markdown]
# # №2

# %%
train = pd.concat([x_train, y_train], axis=1)
train
# Out:
#         Unnamed: 0  STD_ID             НАПРАВЛЕНИЕ        ГОД  КУРС  СЕМЕСТР  \
# 0            51081  175711     38.03.02 Менеджмент  2018-2019   2.0      4.0
# 1            72921  100647  31.05.01 Лечебное дело  2015-2016   3.0      5.0
# 2            96438  199311   31.05.03 Стоматология  2019-2020   1.0      1.0
# 3           273044  162002     38.03.02 Менеджмент  2017-2018   2.0      3.0
# 4           371309  108384  31.05.01 Лечебное дело  2018-2019   5.0      9.0
# ...            ...     ...                     ...        ...   ...      ...
# 105053      224856  176141  40.03.01 Юриспруденция  2017-2018   1.0      2.0
# 105054      260998  182794  31.05.01 Лечебное дело  2018-2019   2.0      4.0
# 105055       57245  162391  31.05.01 Лечебное дело  2016-2017   1.0      2.0
# 105056      218529  202479      38.03.01 Экономика  2017-2018   1.0      1.0
# 105057      233318  182325  08.03.01 Строительство  2018-2019   2.0      3.0
#
#                       АТТЕСТАЦИЯ  \
# ...

# %% [markdown]
# # №3

# %%
studs_info.isna().sum()
# Out:
# STD_ID                            0
#    number                         1
# Пол                               1
# Статус                            1
# Дата выпуска                   5002
# Категория обучения                1
# Форма обучения                    1
# Шифр                              1
# направление (специальность)       1
#                                 191
# Образование                     191
# Дата выдачи                     240
# Что именно закончил             191
# dtype: int64

# %% [markdown]
# # №4

# %%
studs_info.head()
# Out:
#    STD_ID     number Пол Статус Дата выпуска Категория обучения  \
# 0   99136    13951.0   Ж    ВЫП   2019-08-31                 БП
# 1   99112    13998.0   Ж    ВЫП   2019-08-31                 БП
# 2   99109    13999.0   Ж    ВЫП   2019-08-31                 БП
# 3   99125    13953.0   Ж    ВЫП   2019-08-31                 БП
# 4  100676    13950.0   М    ВЫП   2019-08-31                 БП
#
#   Форма обучения      Шифр направление (специальность)         Образование  \
# 0              Д  31.05.01               Лечебное дело  2629.0          СР
# 1              Д  31.05.01               Лечебное дело  8240.0          СР
# 2              Д  31.05.01               Лечебное дело  2314.0          СР
# 3              Д  31.05.01               Лечебное дело  2345.0          СР
# 4              Д  31.05.01               Лечебное дело  2650.0          СР
#
#            Дата выдачи        Что именно закончил
# 0  2013-06-26 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА
# ...

# %%
studs_info["Пол"].value_counts()
# Out:
# Ж    3192
# М    2273
# Name: Пол, dtype: int64

# %% [markdown]
# # №5

# %%
df1 = studs_info[(studs_info["Пол"] == "М") & (studs_info["Дата выпуска"] == "2019-06-30")]
df1.head(3)
# Out:
#     STD_ID     number Пол Статус Дата выпуска Категория обучения  \
# 41  141750    13098.0   М    ВЫП   2019-06-30                 БП
# 52  141829    12000.0   М    ВЫП   2019-06-30                 БП
# 64  139074    12173.0   М    ВЫП   2019-06-30                 БП
#
#    Форма обучения      Шифр направление (специальность)         Образование  \
# 41              Д  38.03.01                   Экономика  4214.0          СР
# 52              Д  11.03.01                Радиотехника  9921.0          СР
# 64              З  35.03.04                   Агрономия  9971.0          СП
#
#             Дата выдачи                     Что именно закончил
# 41  2015-06-26 00:00:00           СРЕДНЯЯ ШКОЛА N  33, НОВГОРОД
# 52  2015-06-26 00:00:00           СРЕДНЯЯ ШКОЛА N  21, НОВГОРОД
# 64  2015-01-30 00:00:00  ГОУ НПО "Агролицей №25" , СТАРАЯ РУССА

# %% [markdown]
# # №6

# %%
data = studs_info["Дата выдачи"].str.split(" |-", expand=True)
data = data.rename(columns={0: "Год выдачи", 1: "Месяц выдачи", 2: "День выдачи", 3: "Время выдачи"})
data
# Out:
#      Год выдачи Месяц выдачи День выдачи Время выдачи
# 0          2013           06          26     00:00:00
# 1          2012           06          23     00:00:00
# 2          2013           06          25     00:00:00
# 3          2013           06          23     00:00:00
# 4          2012           06          29     00:00:00
# ...         ...          ...         ...          ...
# 5461       2013           06          21     00:00:00
# 5462       2013           06          27     00:00:00
# 5463       2014           05          31     00:00:00
# 5464        NaN          NaN         NaN          NaN
# 5465        NaN          NaN         NaN          NaN
#
# [5466 rows x 4 columns]

# %%
studs_info = pd.concat([studs_info, data], axis=1)
studs_info.head(3)
# Out:
#    STD_ID     number Пол Статус Дата выпуска Категория обучения  \
# 0   99136    13951.0   Ж    ВЫП   2019-08-31                 БП
# 1   99112    13998.0   Ж    ВЫП   2019-08-31                 БП
# 2   99109    13999.0   Ж    ВЫП   2019-08-31                 БП
#
#   Форма обучения      Шифр направление (специальность)         Образование  \
# 0              Д  31.05.01               Лечебное дело  2629.0          СР
# 1              Д  31.05.01               Лечебное дело  8240.0          СР
# 2              Д  31.05.01               Лечебное дело  2314.0          СР
#
#            Дата выдачи        Что именно закончил Год выдачи Месяц выдачи  \
# 0  2013-06-26 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА       2013           06
# 1  2012-06-23 00:00:00     МОУ СОШ N   2, ПЕСТОВО       2012           06
# 2  2013-06-25 00:00:00  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА       2013           06
#
#   День выдачи Время выдачи
# 0          26     00:00:00
# 1          23     00:00:00
# ...

# %%
studs_info = studs_info.drop(columns="Дата выдачи")
studs_info.head(3)
# Out:
#    STD_ID     number Пол Статус Дата выпуска Категория обучения  \
# 0   99136    13951.0   Ж    ВЫП   2019-08-31                 БП
# 1   99112    13998.0   Ж    ВЫП   2019-08-31                 БП
# 2   99109    13999.0   Ж    ВЫП   2019-08-31                 БП
#
#   Форма обучения      Шифр направление (специальность)         Образование  \
# 0              Д  31.05.01               Лечебное дело  2629.0          СР
# 1              Д  31.05.01               Лечебное дело  8240.0          СР
# 2              Д  31.05.01               Лечебное дело  2314.0          СР
#
#          Что именно закончил Год выдачи Месяц выдачи День выдачи Время выдачи
# 0  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА       2013           06          26     00:00:00
# 1     МОУ СОШ N   2, ПЕСТОВО       2012           06          23     00:00:00
# 2  ИНОГОРОДНЯЯ СРЕДНЯЯ ШКОЛА       2013           06          25     00:00:00

# %% [markdown]
# # №7

# %%
studs_info["Статус"].value_counts()
# Out:
# СТ     5001
# ВЫП     464
# Name: Статус, dtype: int64

# %% [markdown]
# # №8

# %%
y_train.head()
# Out:
#     index  mark
# 0   51081     5
# 1   72921     5
# 2   96438     5
# 3  273044     4
# 4  371309     3

# %%
y_train["mark"].value_counts()
# Out:
# 4    42217
# 5    41085
# 3    21756
# Name: mark, dtype: int64

# %% [markdown]
# # №9

# %%
train[train["STD_ID"] == 175711.0]["mark"].mean()
# Out:
# 4.181818181818182

# %% [markdown]
# # №10

# %%
train = train.drop(columns="index")
train
# Out:
#         Unnamed: 0  STD_ID             НАПРАВЛЕНИЕ        ГОД  КУРС  СЕМЕСТР  \
# 0            51081  175711     38.03.02 Менеджмент  2018-2019   2.0      4.0
# 1            72921  100647  31.05.01 Лечебное дело  2015-2016   3.0      5.0
# 2            96438  199311   31.05.03 Стоматология  2019-2020   1.0      1.0
# 3           273044  162002     38.03.02 Менеджмент  2017-2018   2.0      3.0
# 4           371309  108384  31.05.01 Лечебное дело  2018-2019   5.0      9.0
# ...            ...     ...                     ...        ...   ...      ...
# 105053      224856  176141  40.03.01 Юриспруденция  2017-2018   1.0      2.0
# 105054      260998  182794  31.05.01 Лечебное дело  2018-2019   2.0      4.0
# 105055       57245  162391  31.05.01 Лечебное дело  2016-2017   1.0      2.0
# 105056      218529  202479      38.03.01 Экономика  2017-2018   1.0      1.0
# 105057      233318  182325  08.03.01 Строительство  2018-2019   2.0      3.0
#
#                       АТТЕСТАЦИЯ  \
# ...
