# %% [markdown]
# # Домашнее задание

# %% [markdown]
# В домашнем задании вам необходимо рассмтреть данные с олимпиады НТИ по профилю "Исскусственный интеллект" за 2019-2020 год.
#
# Задачу можно найти по ссылке:
#
# https://www.kaggle.com/c/onti-students-performance/data

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/X_train.csv'
X_train = pd.read_csv(url)
url = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/studs_info.csv'
studs_info = pd.read_csv(url)
url = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/y_train.csv'
y_train = pd.read_csv(url)
url = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/zachety.csv'
zachety = pd.read_csv(url)

# %% [markdown]
# ## Вариант 2.

# %% [markdown]
# Кто делает:
# 1. Зверев Александр Александрович
# 2. Зимина Александра Георгиевна
# 3. Иванов Александр Андреевич
# 4. Калентьев (Топилин) Константин Юрьевич
# 5. Мартюшев Владислав Алексеевич

# %% [markdown]
# 1. Посмотреть размерность дата фреймов.

# %%
print(X_train.shape)
print(studs_info.shape)
print(y_train.shape)
print(zachety.shape)

# %% [markdown]
# 2. Соедить два датафрейма X_train и y_train в один train по индексам.

# %%
pd.concat([X_train, y_train], ignore_index=False)

# %% [markdown]
# 3. Посчитать пропуски в датафрейме studs_info.

# %%
si = studs_info.isna().sum()
s=0
for i in si:
  s+=i
s

# %% [markdown]
# 4. Посчитать сколько мужчин, сколько женщин в датафрейме studs_info.

# %%
g = studs_info['Пол']
m = 0
w = 0
for i in g:
  if (i=='М'): m+=1
  else: w+=1
print(m)
print(w)

# %% [markdown]
# 5. Создать новый датафрейм из studs_info, в котором будут только мужчины 2019-06-30 года выпуска.

# %%
new = studs_info
new = new[new['Пол'] == 'М']
new = new[new['Дата выпуска'] == '2019-06-30']
new

# %% [markdown]
# 6. Разложить колонку "Дата выдачи" на четыре: Год выдачи, Месяц выдачи, День выдачи, Время выдачи. -

# %%
# не работает
new = pd.DataFrame(columns=['Год выдачи', 'Месяц выдачи', 'День выдачи'])
data = studs_info['Дата выдачи']
for i in range(data.size):
  new.iloc[i, 'Год выдачи'] = str(data[i]).split('-')[0]
  new.iloc[i, 'Месяц выдачи'] = str(data[i]).split('-')[1]
  new.iloc[i, 'День выдачи'] = str(data[i]).split('-')[2]
new

# %% [markdown]
# 7. Посчитать сколько уникальных значений в колонке studs_info['Статус'] и сколько раз каждое значение встречается в датафрейм.

# %%
print(studs_info['Статус'].unique())
print(studs_info['Статус'].value_counts())

# %% [markdown]
# 8. Посчитать сколько раз какая оценка встречатся в датафрейм y_train.

# %%
y_train['mark'].value_counts()

# %% [markdown]
# 9. Посчитать средний балл для студента с ID=175711 по всем предметам.

# %%
rabota = X_train[X_train['STD_ID'] == 175711]
rabota = rabota['Unnamed: 0']
temp = rabota.index
kolvo = 0
summ = 0
for i in temp:
  kolvo += 1
  summ += y_train.iloc[i, 1]
print(summ / kolvo)

# %% [markdown]
# 10. Удалить любую ненужны колонку на ваш вгляд из датафрейм train.

# %%
X_train.drop(columns = ['АТТЕСТАЦИЯ'])
