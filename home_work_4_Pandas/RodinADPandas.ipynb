# %%
import pandas
import numpy

url_xtrain_csv = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/X_train.csv'
url_ytrain_csv = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/y_train.csv'
url_info_csv = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/studs_info.csv'
url_exams_csv = 'https://raw.githubusercontent.com/Adelaaas/Data_science_basic_22-23_1/main/class_work_4_Pandas/ONTI%20Students%20performance/zachety.csv'

xtrain_csv = pandas.read_csv(url_xtrain_csv)
ytrain_csv = pandas.read_csv(url_ytrain_csv)
info_csv = pandas.read_csv(url_info_csv)
exams_csv = pandas.read_csv(url_exams_csv)

# %%
#1 задание

print(xtrain_csv.shape, ytrain_csv.shape, info_csv.shape, exams_csv.shape)
# Out:
# (105058, 8) (105058, 2) (5466, 13) (133223, 8)

# %%
#2 задание

xytrain = pandas.concat([xtrain_csv, ytrain_csv],axis=1)
xytrain
# Out:
#         Unnamed: 0  STD_ID             НАПРАВЛЕНИЕ        ГОД  КУРС  СЕМЕСТР  \
# 0            51081  175711     38.03.02 Менеджмент  2018-2019   2.0      4.0
# 1            72921  100647  31.05.01 Лечебное дело  2015-2016   3.0      5.0
# 2            96438  199311   31.05.03 Стоматология  2019-2020   1.0      1.0
# 3           273044  162002     38.03.02 Менеджмент  2017-2018   2.0      3.0
# 4           371309  108384  31.05.01 Лечебное дело  2018-2019   5.0      9.0
# ...            ...     ...                     ...        ...   ...      ...
# 105053      224856  176141  40.03.01 Юриспруденция  2017-2018   1.0      2.0
# 105054      260998  182794  31.05.01 Лечебное дело  2018-2019   2.0      4.0
# 105055       57245  162391  31.05.01 Лечебное дело  2016-2017   1.0      2.0
# 105056      218529  202479      38.03.01 Экономика  2017-2018   1.0      1.0
# 105057      233318  182325  08.03.01 Строительство  2018-2019   2.0      3.0
#
#                       АТТЕСТАЦИЯ  \
# ...

# %%
#3 задание

info_csv.isna().sum().sum()
# Out:
# 5822

# %%
#4 задание

print(xytrain['АТТЕСТАЦИЯ'].unique())
print(xytrain['АТТЕСТАЦИЯ'].value_counts())
# Out:
# ['Экзамен' 'Курсовая работа' 'Дифференцированный зачет' 'Курсовой проект'
#  'Зачет']
# Экзамен                     60092
# Дифференцированный зачет    37791
# Курсовая работа              5522
# Курсовой проект              1631
# Зачет                          22
# Name: АТТЕСТАЦИЯ, dtype: int64

# %%
#5 задание

xytrain.columns = [i.lower() for i in xytrain.columns]
xytrain
# Out:
#         unnamed: 0  std_id             направление        год  курс  семестр  \
# 0            51081  175711     38.03.02 Менеджмент  2018-2019   2.0      4.0
# 1            72921  100647  31.05.01 Лечебное дело  2015-2016   3.0      5.0
# 2            96438  199311   31.05.03 Стоматология  2019-2020   1.0      1.0
# 3           273044  162002     38.03.02 Менеджмент  2017-2018   2.0      3.0
# 4           371309  108384  31.05.01 Лечебное дело  2018-2019   5.0      9.0
# ...            ...     ...                     ...        ...   ...      ...
# 105053      224856  176141  40.03.01 Юриспруденция  2017-2018   1.0      2.0
# 105054      260998  182794  31.05.01 Лечебное дело  2018-2019   2.0      4.0
# 105055       57245  162391  31.05.01 Лечебное дело  2016-2017   1.0      2.0
# 105056      218529  202479      38.03.01 Экономика  2017-2018   1.0      1.0
# 105057      233318  182325  08.03.01 Строительство  2018-2019   2.0      3.0
#
#                       аттестация  \
# ...

# %%
#6 задание

dc = {'Код направления':[],'Название направления': []}
for i in range(xytrain.shape[0]):
    code, name = map(str, str(xytrain.iloc[i][2]).split(maxsplit=1))
    dc['Код направления'].append(ConnectionRefusedError)
    dc['Название направления'].append(name)

df = pandas.DataFrame(dc)
xytrain = pandas.concat([xytrain,df],axis=1)
xytrain.drop(['направление'],axis=1,inplace=True)

xytrain
# Out:
#         unnamed: 0  std_id        год  курс  семестр  \
# 0            51081  175711  2018-2019   2.0      4.0
# 1            72921  100647  2015-2016   3.0      5.0
# 2            96438  199311  2019-2020   1.0      1.0
# 3           273044  162002  2017-2018   2.0      3.0
# 4           371309  108384  2018-2019   5.0      9.0
# ...            ...     ...        ...   ...      ...
# 105053      224856  176141  2017-2018   1.0      2.0
# 105054      260998  182794  2018-2019   2.0      4.0
# 105055       57245  162391  2016-2017   1.0      2.0
# 105056      218529  202479  2017-2018   1.0      1.0
# 105057      233318  182325  2018-2019   2.0      3.0
#
#                       аттестация  \
# 0                        Экзамен
# 1                        Экзамен
# 2                        Экзамен
# 3                        Экзамен
# 4                        Экзамен
# ...                          ...
# 105053           Курсовая работа
# 105054                   Экзамен
# ...

# %%
#8 задание

d = {'Пол': []}
for i in range(info_csv.shape[0]):
  d['Пол'].append(0  if (info_csv.loc[i]['Пол']=='М') else  1)

studs_info_csv_intGender = pandas.DataFrame(d)

info_csv.drop(['Пол'], axis=1, inplace=True)
info_csv = pandas.concat([info_csv,studs_info_csv_intGender],axis=1)
info_csv
# Out:
#       STD_ID     number Статус Дата выпуска Категория обучения Форма обучения  \
# 0      99136    13951.0    ВЫП   2019-08-31                 БП              Д
# 1      99112    13998.0    ВЫП   2019-08-31                 БП              Д
# 2      99109    13999.0    ВЫП   2019-08-31                 БП              Д
# 3      99125    13953.0    ВЫП   2019-08-31                 БП              Д
# 4     100676    13950.0    ВЫП   2019-08-31                 БП              Д
# ...      ...        ...    ...          ...                ...            ...
# 5461  100678      978.0     СТ          NaN                 БП              Д
# 5462  100663     1021.0     СТ          NaN                ДОГ              Д
# 5463  191630     6447.0     СТ          NaN                ДОГ              Д
# 5464  191625     3765.0     СТ          NaN                ДОГ              Д
# 5465  194978     5245.0     СТ          NaN                ДОГ              Д
#
# ...

# %%
#9 задание

inf_ekz = xytrain[xytrain['дисциплина']=='Информатика'][xytrain['аттестация']=='Экзамен']
print(inf_ekz.shape[0], inf_ekz['mark'].sum()/inf_ekz.shape[0])
# Out:
# 60 4.6
# <ipython-input-14-90fa1ff06a4b>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   inf_ekz = xytrain[xytrain['дисциплина']=='Информатика'][xytrain['аттестация']=='Экзамен']
